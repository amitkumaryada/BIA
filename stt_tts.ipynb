# %%
# ! pip install --upgrade pip
! pip install SpeechRecognition
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 3.2 MB/s  0:00:10m0:00:0100:01
# ...

# %%
! pip install pyttsx3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 678.3/678.3 kB 2.4 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160/160 [pyttsx3][pyobjc]yobjc-framework-AVFoundation]
# ...

# %%
! pip install pyaudio
# Out:
# ...
#   Using cached pyaudio-0.2.14-cp312-cp312-macosx_10_13_universal2.whl
# ...

# %%
! pip install nltk

# %%
import speech_recognition as sr
def listen_to_user():
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        audio = recognizer.listen(source, timeout=5)
        text = recognizer.recognize_google(audio)
        return text.lower()

# %%
listen_to_user()
# Out:
# 'hello how are you'

# %%
import pyttsx3
def speak_to_user(text):
    engine = pyttsx3.init()
    engine.setProperty('rate', 150)    # Speed
    engine.setProperty('volume', 0.9)  # Volume
    engine.say(text)
    engine.runAndWait()

# %%
import pyttsx3

engine = pyttsx3.init()
voices = engine.getProperty('voices')

for i, voice in enumerate(voices):
    print(f"Voice {i}:")
    print(f" - ID: {voice.id}")
    print(f" - Name: {voice.name}")
    print(f" - Languages: {voice.languages}")
    print(f" - Gender: {voice.gender}")
    print(f" - Age: {voice.age}")
    print()
# Out:
# Voice 0:
#  - ID: com.apple.speech.synthesis.voice.Albert
#  - Name: Albert
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 1:
#  - ID: com.apple.voice.compact.it-IT.Alice
#  - Name: Alice
#  - Languages: ['it_IT']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 2:
#  - ID: com.apple.voice.compact.sv-SE.Alva
#  - Name: Alva
#  - Languages: ['sv_SE']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 3:
#  - ID: com.apple.voice.compact.fr-CA.Amelie
#  - Name: Amélie
#  - Languages: ['fr_CA']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 4:
#  - ID: com.apple.voice.compact.ms-MY.Amira
#  - Name: Amira
#  - Languages: ['ms_MY']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 5:
#  - ID: com.apple.voice.compact.de-DE.Anna
#  - Name: Anna
#  - Languages: ['de_DE']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 6:
#  - ID: com.apple.speech.synthesis.voice.BadNews
#  - Name: Bad News
#  - Languages: ['en_US']
# ...

# %%
speak_to_user("This is a  mic check, hello, hello ,1 ,2,3.dsvkjlbvbjaabjvffbjkdfablblavalbafbjabdfj;knj;bdaflmbdfanlbfadnlbvlan,sfk;jhgdshjk;gs,,sdjflGSAJLHGSAFLHJF,USDFKHJFSDGJXCVLSJFDSUYA;vbjlbadfv.adfknj")

# %%
intents = {
    'greeting': ['hello', 'hi', 'hey'],
    'time': ['time', 'what time', 'clock'],
    'calculate': ['calculate', 'math', 'plus', 'minus']
}

class VoiceBot:
    def __init__(self, name="Alex"):
        self.name = name

    def listen(self):  # STT functionality
        recognizer = sr.Recognizer()
        with sr.Microphone() as source:
            print("Listening...")
            audio = recognizer.listen(source, timeout=5)
            text = recognizer.recognize_google(audio)
            print(f"You said: {text}")
            return text.lower()

    def speak(self, text):
        engine = pyttsx3.init()
        engine.setProperty('rate', 150)
        engine.setProperty('volume', 0.9)
        engine.say(text)
        engine.runAndWait()

    def process_intent(self, text):
        # Check if any keyword from each intent category is in the user's text
        for keyword in intents['greeting']:
            if keyword in text:
                return "How may I help you?"
        
        for keyword in intents['time']:
            if keyword in text:
                return "It is 12pm"
        
        for keyword in intents['calculate']:
            if keyword in text:
                return "I have no math capabilities"
        
        return "I am yet to be defined for this capability"

    def run(self):
        input_text = self.listen()
        tts = self.process_intent(input_text)
        speak = self.speak(tts)
        return speak
        


vb = VoiceBot()
vb.run()
# Out:
# Listening...
# You said: hello
